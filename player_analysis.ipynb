# %%
import pandas as pd

# %% [markdown]
# ### Import Dataset

# %%
final_events_1 = pd.read_json("final_events_1.json")
final_events_2 = pd.read_json("final_events_2.json")

# %%
final_events_1
# Out:
#            id                                       photo_link  \
# 0           1      https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 1           1      https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 2           1      https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 3           1      https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 4           1      https://d2a3o6pzho379u.cloudfront.net/1.jpg
# ...       ...                                              ...
# 153443  73859                                             None
# 153444  73859                                             None
# 153445  73860  https://d2a3o6pzho379u.cloudfront.net/73860.jpg
# 153446  73861                                             None
# 153447  73861                                             None
#
#                             Roles   Sex  \
# 0       Competed in Olympic Games  Male
# 1       Competed in Olympic Games  Male
# 2       Competed in Olympic Games  Male
# 3       Competed in Olympic Games  Male
# ...

# %%
final_events_2
# Out:
#             id                                        photo_link  \
# 0        73861                                              None
# 1        73862   https://d2a3o6pzho379u.cloudfront.net/73862.jpg
# 2        73862   https://d2a3o6pzho379u.cloudfront.net/73862.jpg
# 3        73862   https://d2a3o6pzho379u.cloudfront.net/73862.jpg
# 4        73863   https://d2a3o6pzho379u.cloudfront.net/73863.jpg
# ...        ...                                               ...
# 153443  149222                                              None
# 153444  149223                                              None
# 153445  149224                                              None
# 153446  149225  https://d2a3o6pzho379u.cloudfront.net/149225.jpg
# 153447  149814                                              None
#
#                               Roles     Sex  \
# 0         Competed in Olympic Games    Male
# 1         Competed in Olympic Games    Male
# 2         Competed in Olympic Games    Male
# ...

# %% [markdown]
# #### Concat the dataframe

# %%
final_events_concat = pd.concat([final_events_1, final_events_2], ignore_index=True, sort=False).drop(columns=["Events"])

# %%
final_events_concat
# Out:
#             id                                        photo_link  \
# 0            1       https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 1            1       https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 2            1       https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 3            1       https://d2a3o6pzho379u.cloudfront.net/1.jpg
# 4            1       https://d2a3o6pzho379u.cloudfront.net/1.jpg
# ...        ...                                               ...
# 306891  149222                                              None
# 306892  149223                                              None
# 306893  149224                                              None
# 306894  149225  https://d2a3o6pzho379u.cloudfront.net/149225.jpg
# 306895  149814                                              None
#
#                               Roles     Sex  \
# 0         Competed in Olympic Games    Male
# 1         Competed in Olympic Games    Male
# 2         Competed in Olympic Games    Male
# ...

# %% [markdown]
# #### Save to CSV

# %%
# final_events_concat.to_csv("events.csv", sep=";")

# %% [markdown]
# ### Data Analysis

# %%
final_events_concat.isnull().sum()
# Out:
# id                    0
# photo_link        63484
# Roles                 0
# Sex                   0
# Full_name             0
# Used_name             0
# Born               2537
# Died             234237
# NOC                   0
# game                  0
# discipline            0
# noc                   0
# Measurements      69058
# Affiliations      93015
# Nick/petnames    283831
# Title(s)         305896
# Other_names      290923
# Nationality      288143
# Original_name    243532
# Name_order       291283
# event                95
# team                 95
# position             95
# medal                95
# dtype: int64
